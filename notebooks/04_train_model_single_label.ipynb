# %%
import json
import numpy as np
import pandas as pd
import torch
import re
import string
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer
from transformers import CLIPModel, CLIPTokenizer
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.multiclass import OneVsRestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

# %%
model_bert = SentenceTransformer('all-MiniLM-L6-v2')
model_clip = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-base-patch32")

# %%
def compute_tfidf(text_list):
    vectorizer = TfidfVectorizer(stop_words='english', max_features=3000, sublinear_tf=True)
    vectors = vectorizer.fit_transform(text_list)
    return vectors.toarray()

# %%
def compute_sentence_embeddings(text_list, batch_size=256):
    embeddings = []
    text_list = [text.strip() for text in text_list]

    for i in range(0, len(text_list), batch_size):
        batch = text_list[i:i + batch_size]
        batch_embeddings = model_bert.encode(batch)
        embeddings.append(batch_embeddings)

    # Concatenate all batch embeddings
    return np.vstack(embeddings)

# %%
def compute_clip_embeddings(text_list, batch_size=256):
    embeddings = []
    for i in range(0, len(text_list), batch_size):
        batch = text_list[i:i + batch_size]
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt")
        with torch.no_grad():
            batch_embeddings = model_clip.get_text_features(**inputs).cpu().numpy()
        embeddings.append(batch_embeddings)
    return np.vstack(embeddings)

# %%
def train_random_forest_with_undersampling(X, y, embedding_name, source_text):
    # Stratified K-Fold for cross-validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Random undersampling for balancing classes
    #rus = RandomUnderSampler(sampling_strategy='not minority', random_state=42)

    # Create the RandomForest model
    base_rf = RandomForestClassifier(n_estimators=100, random_state=42)

    # One-vs-Rest Classifier with custom pipeline that applies undersampling
    clf = OneVsRestClassifier(
        make_pipeline(RandomUnderSampler(sampling_strategy='not minority', random_state=42), base_rf),
        verbose=2
    )
    
    accuracy_scores = []
    precision_scores = []
    recall_scores = []
    f1_scores = []

    # Cross-validation loop
    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)

        # Evaluation metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')

        accuracy_scores.append(accuracy)
        precision_scores.append(precision)
        recall_scores.append(recall)
        f1_scores.append(f1)

        print(f'Fold Results for {embedding_name} (OvR Random Forest) - {source_text}:')
        print(classification_report(y_test, y_pred))
        print(f'Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}')
        print('-----------------------------------')

    # Average metrics over all folds
    print(f'Final Cross-Validated Results for {embedding_name} (OvR Random Forest) - {source_text}:')
    print(f'Average Accuracy: {sum(accuracy_scores)/len(accuracy_scores):.4f}')
    print(f'Average Precision: {sum(precision_scores)/len(precision_scores):.4f}')
    print(f'Average Recall: {sum(recall_scores)/len(recall_scores):.4f}')
    print(f'Average F1-Score: {sum(f1_scores)/len(f1_scores):.4f}')

# %%
def evaluate_clustering_metrics(X, y, embedding_name, source_text):
    print(f'Clustering metrics for {embedding_name} - {source_text}:')
    # Calculate metrics
    silhouette_avg = silhouette_score(X, y)
    calinski_harabasz = calinski_harabasz_score(X, y)
    davies_bouldin = davies_bouldin_score(X, y)
    
    # Return results in a dictionary
    metrics = {
        'Silhouette Score': silhouette_avg,
        'Calinski-Harabasz Index': calinski_harabasz,
        'Davies-Bouldin Index': davies_bouldin
    }
    
    table = [["Metric", "Score"]]
    for metric, score in metrics.items():
        table.append([metric, f"{score:.4f}"])
    
    print(f'Clustering metrics for {embedding_name} (OvR Random Forest) - {source_text}:')
    print(f'Silhouette Score: {silhouette_avg:.4f}')
    print(f'Calinski-Harabasz Index: {calinski_harabasz:.4f}')
    print(f'Davies-Bouldin Index: {davies_bouldin:.4f}')

# %%
print('Load data')
with open('../data/published_data/paper_title_abstract_dataset.json', 'r') as f:
    papers_data = json.load(f)

df = pd.DataFrame(papers_data)
print(f'Number of samples: {df.shape[0]}')

titles = df['paper_title'].tolist()
abstracts = df['abstract'].tolist()
readmes = df['github_readme_content'].tolist()
# Out:
# Load data
# Number of samples: 16093

# %%
print('Load data for somef decriptions')
with open('../data/published_data/paper_title_abstract_software_readme_description_dataset.json', 'r') as f:
    papers_data_somef = json.load(f)

df_somef = pd.DataFrame(papers_data_somef)
print(f'Number of samples: {df_somef.shape[0]}')

somef = df_somef['somef_descriptions'].tolist()
# Out:
# Load data for somef decriptions
# Number of samples: 13474

# %%
print('Load data for github titles and keywords')
with open('../data/published_data/paper_title_abstract_software_readme_description_title_keyword_dataset.json', 'r') as f:
    papers_data_complete = json.load(f)

df_complete = pd.DataFrame(papers_data_complete)
print(f'Number of samples: {df_complete.shape[0]}')
github_title = df_complete['github_repo_title'].tolist()
github_keywords = df_complete['github_keywords'].tolist()
# Out:
# Load data for github titles and keywords
# Number of samples: 2904

# %%
y = df['main_collection_area']
y_somef = df_somef['main_collection_area']
y_complete = df_complete['main_collection_area']
num_clusters = len(y.unique())

# %%
tfidf_embeddings = compute_tfidf(titles)
train_random_forest_with_undersampling(tfidf_embeddings, y, 'TF-IDF', 'Title')
# evaluate_clustering_metrics(tfidf_embeddings, y, 'TF-IDF', 'Title')
# Out:
# Fold Results for TF-IDF (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.25      0.11         8
#             Computer Vision       0.88      0.65      0.75      1929
#                      Graphs       0.67      0.65      0.66       575
# Natural Language Processing       0.40      0.58      0.48       530
#      Reinforcement Learning       0.34      0.55      0.42       148
#                  Sequential       0.07      0.48      0.12        29
#
#                    accuracy                           0.64      3219
#                   macro avg       0.41      0.53      0.42      3219
#                weighted avg       0.73      0.64      0.67      3219
#
# Accuracy: 0.6353, Precision: 0.7329, Recall: 0.6353, F1-Score: 0.6684
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.25      0.11         8
#             Computer Vision       0.88      0.64      0.74      1929
#                      Graphs       0.62      0.64      0.63       575
# Natural Language Processing       0.38      0.57      0.45       529
#      Reinforcement Learning       0.34      0.60      0.44       149
#                  Sequential       0.08      0.38      0.14        29
#
#                    accuracy                           0.62      3219
#                   macro avg       0.39      0.51      0.42      3219
#                weighted avg       0.71      0.62      0.65      3219
#
# Accuracy: 0.6216, Precision: 0.7138, Recall: 0.6216, F1-Score: 0.6508
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      0.38      0.10         8
#             Computer Vision       0.88      0.64      0.74      1929
#                      Graphs       0.66      0.65      0.66       575
# Natural Language Processing       0.41      0.60      0.48       529
#      Reinforcement Learning       0.36      0.66      0.47       149
#                  Sequential       0.07      0.38      0.12        29
#
#                    accuracy                           0.63      3219
#                   macro avg       0.41      0.55      0.43      3219
#                weighted avg       0.73      0.63      0.66      3219
#
# Accuracy: 0.6322, Precision: 0.7313, Recall: 0.6322, F1-Score: 0.6642
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.57      0.09         7
#             Computer Vision       0.90      0.63      0.74      1928
#                      Graphs       0.67      0.69      0.68       576
# Natural Language Processing       0.41      0.57      0.48       529
#      Reinforcement Learning       0.31      0.64      0.42       149
#                  Sequential       0.09      0.38      0.14        29
#
#                    accuracy                           0.63      3218
#                   macro avg       0.40      0.58      0.42      3218
#                weighted avg       0.74      0.63      0.66      3218
#
# Accuracy: 0.6302, Precision: 0.7399, Recall: 0.6302, F1-Score: 0.6646
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.25      0.03         8
#             Computer Vision       0.91      0.61      0.73      1928
#                      Graphs       0.66      0.68      0.67       576
# Natural Language Processing       0.39      0.58      0.46       529
#      Reinforcement Learning       0.43      0.66      0.52       149
#                  Sequential       0.06      0.36      0.10        28
#
#                    accuracy                           0.61      3218
#                   macro avg       0.41      0.52      0.42      3218
#                weighted avg       0.75      0.61      0.66      3218
#
# Accuracy: 0.6140, Precision: 0.7456, Recall: 0.6140, F1-Score: 0.6567
# -----------------------------------
# Final Cross-Validated Results for TF-IDF (OvR Random Forest) - Title:
# Average Accuracy: 0.6267
# Average Precision: 0.7327
# Average Recall: 0.6267
# Average F1-Score: 0.6609

# %%
sentence_embeddings = compute_sentence_embeddings(titles)
train_random_forest_with_undersampling(sentence_embeddings, y, 'Sentence Transformer', 'Title')
# evaluate_clustering_metrics(sentence_embeddings, y, 'Sentence Transformer', 'Title')
# Out:
# Fold Results for Sentence Transformer (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.75      0.12         8
#             Computer Vision       0.85      0.67      0.75      1929
#                      Graphs       0.62      0.58      0.60       575
# Natural Language Processing       0.41      0.50      0.45       530
#      Reinforcement Learning       0.37      0.64      0.47       148
#                  Sequential       0.07      0.45      0.13        29
#
#                    accuracy                           0.62      3219
#                   macro avg       0.40      0.60      0.42      3219
#                weighted avg       0.71      0.62      0.65      3219
#
# Accuracy: 0.6222, Precision: 0.7072, Recall: 0.6222, F1-Score: 0.6536
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.88      0.10         8
#             Computer Vision       0.85      0.65      0.74      1929
#                      Graphs       0.59      0.58      0.58       575
# Natural Language Processing       0.42      0.50      0.45       529
#      Reinforcement Learning       0.39      0.64      0.48       149
#                  Sequential       0.09      0.48      0.15        29
#
#                    accuracy                           0.61      3219
#                   macro avg       0.40      0.62      0.42      3219
#                weighted avg       0.70      0.61      0.65      3219
#
# Accuracy: 0.6129, Precision: 0.7045, Recall: 0.6129, F1-Score: 0.6462
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.50      0.09         8
#             Computer Vision       0.84      0.64      0.73      1929
#                      Graphs       0.58      0.57      0.58       575
# Natural Language Processing       0.40      0.51      0.45       529
#      Reinforcement Learning       0.38      0.69      0.49       149
#                  Sequential       0.06      0.34      0.10        29
#
#                    accuracy                           0.61      3219
#                   macro avg       0.39      0.54      0.41      3219
#                weighted avg       0.69      0.61      0.64      3219
#
# Accuracy: 0.6058, Precision: 0.6925, Recall: 0.6058, F1-Score: 0.6365
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.57      0.08         7
#             Computer Vision       0.85      0.67      0.75      1928
#                      Graphs       0.66      0.59      0.62       576
# Natural Language Processing       0.43      0.52      0.47       529
#      Reinforcement Learning       0.40      0.74      0.52       149
#                  Sequential       0.05      0.34      0.09        29
#
#                    accuracy                           0.63      3218
#                   macro avg       0.41      0.57      0.42      3218
#                weighted avg       0.72      0.63      0.66      3218
#
# Accuracy: 0.6290, Precision: 0.7189, Recall: 0.6290, F1-Score: 0.6621
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      0.50      0.11         8
#             Computer Vision       0.86      0.65      0.74      1928
#                      Graphs       0.59      0.63      0.61       576
# Natural Language Processing       0.43      0.51      0.46       529
#      Reinforcement Learning       0.39      0.70      0.50       149
#                  Sequential       0.08      0.43      0.13        28
#
#                    accuracy                           0.63      3218
#                   macro avg       0.40      0.57      0.43      3218
#                weighted avg       0.71      0.63      0.65      3218
#
# Accuracy: 0.6259, Precision: 0.7072, Recall: 0.6259, F1-Score: 0.6537
# -----------------------------------
# Final Cross-Validated Results for Sentence Transformer (OvR Random Forest) - Title:
# Average Accuracy: 0.6192
# Average Precision: 0.7060
# Average Recall: 0.6192
# Average F1-Score: 0.6504

# %%
clip_embeddings = compute_clip_embeddings(titles)
train_random_forest_with_undersampling(clip_embeddings, y, 'CLIP', 'Title')
# evaluate_clustering_metrics(clip_embeddings, y, 'CLIP', 'Title')
# Out:
# Fold Results for CLIP (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.25      0.04         8
#             Computer Vision       0.85      0.62      0.72      1929
#                      Graphs       0.60      0.53      0.56       575
# Natural Language Processing       0.40      0.45      0.42       530
#      Reinforcement Learning       0.27      0.56      0.37       148
#                  Sequential       0.04      0.45      0.08        29
#
#                    accuracy                           0.57      3219
#                   macro avg       0.36      0.48      0.36      3219
#                weighted avg       0.69      0.57      0.62      3219
#
# Accuracy: 0.5732, Precision: 0.6921, Recall: 0.5732, F1-Score: 0.6180
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.50      0.06         8
#             Computer Vision       0.84      0.57      0.68      1929
#                      Graphs       0.55      0.51      0.53       575
# Natural Language Processing       0.39      0.45      0.42       529
#      Reinforcement Learning       0.32      0.60      0.41       149
#                  Sequential       0.04      0.45      0.07        29
#
#                    accuracy                           0.54      3219
#                   macro avg       0.36      0.51      0.36      3219
#                weighted avg       0.68      0.54      0.59      3219
#
# Accuracy: 0.5430, Precision: 0.6805, Recall: 0.5430, F1-Score: 0.5921
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.62      0.07         8
#             Computer Vision       0.83      0.57      0.68      1929
#                      Graphs       0.57      0.52      0.54       575
# Natural Language Processing       0.39      0.43      0.41       529
#      Reinforcement Learning       0.27      0.57      0.36       149
#                  Sequential       0.04      0.41      0.07        29
#
#                    accuracy                           0.54      3219
#                   macro avg       0.35      0.52      0.35      3219
#                weighted avg       0.67      0.54      0.59      3219
#
# Accuracy: 0.5371, Precision: 0.6748, Recall: 0.5371, F1-Score: 0.5866
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.43      0.07         7
#             Computer Vision       0.83      0.62      0.71      1928
#                      Graphs       0.63      0.55      0.59       576
# Natural Language Processing       0.37      0.48      0.42       529
#      Reinforcement Learning       0.28      0.57      0.38       149
#                  Sequential       0.04      0.31      0.08        29
#
#                    accuracy                           0.58      3218
#                   macro avg       0.37      0.49      0.37      3218
#                weighted avg       0.69      0.58      0.62      3218
#
# Accuracy: 0.5817, Precision: 0.6867, Recall: 0.5817, F1-Score: 0.6201
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      0.50      0.10         8
#             Computer Vision       0.84      0.61      0.70      1928
#                      Graphs       0.57      0.53      0.55       576
# Natural Language Processing       0.38      0.48      0.42       529
#      Reinforcement Learning       0.30      0.58      0.39       149
#                  Sequential       0.03      0.32      0.06        28
#
#                    accuracy                           0.57      3218
#                   macro avg       0.36      0.50      0.37      3218
#                weighted avg       0.68      0.57      0.61      3218
#
# Accuracy: 0.5684, Precision: 0.6822, Recall: 0.5684, F1-Score: 0.6094
# -----------------------------------
# Final Cross-Validated Results for CLIP (OvR Random Forest) - Title:
# Average Accuracy: 0.5607
# Average Precision: 0.6833
# Average Recall: 0.5607
# Average F1-Score: 0.6052

# %%
tfidf_embeddings = compute_tfidf(abstracts)
train_random_forest_with_undersampling(tfidf_embeddings, y, 'TF-IDF', 'Abstract')
# evaluate_clustering_metrics(tfidf_embeddings, y, 'TF-IDF', 'Abstract')
# Out:
# Fold Results for TF-IDF (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.15      0.50      0.23         8
#             Computer Vision       0.96      0.88      0.92      1929
#                      Graphs       0.81      0.84      0.83       575
# Natural Language Processing       0.84      0.86      0.85       530
#      Reinforcement Learning       0.62      0.81      0.70       148
#                  Sequential       0.24      0.66      0.36        29
#
#                    accuracy                           0.87      3219
#                   macro avg       0.60      0.76      0.65      3219
#                weighted avg       0.89      0.87      0.88      3219
#
# Accuracy: 0.8670, Precision: 0.8887, Recall: 0.8670, F1-Score: 0.8753
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.50      0.09         8
#             Computer Vision       0.96      0.85      0.90      1929
#                      Graphs       0.78      0.85      0.81       575
# Natural Language Processing       0.81      0.80      0.80       529
#      Reinforcement Learning       0.60      0.72      0.66       149
#                  Sequential       0.17      0.55      0.26        29
#
#                    accuracy                           0.83      3219
#                   macro avg       0.56      0.71      0.59      3219
#                weighted avg       0.87      0.83      0.85      3219
#
# Accuracy: 0.8322, Precision: 0.8742, Recall: 0.8322, F1-Score: 0.8495
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.25      0.04         8
#             Computer Vision       0.96      0.86      0.91      1929
#                      Graphs       0.81      0.84      0.82       575
# Natural Language Processing       0.83      0.85      0.84       529
#      Reinforcement Learning       0.63      0.81      0.71       149
#                  Sequential       0.30      0.62      0.40        29
#
#                    accuracy                           0.85      3219
#                   macro avg       0.59      0.71      0.62      3219
#                weighted avg       0.89      0.85      0.86      3219
#
# Accuracy: 0.8472, Precision: 0.8881, Recall: 0.8472, F1-Score: 0.8644
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.29      0.05         7
#             Computer Vision       0.96      0.85      0.90      1928
#                      Graphs       0.81      0.85      0.83       576
# Natural Language Processing       0.83      0.85      0.84       529
#      Reinforcement Learning       0.60      0.83      0.69       149
#                  Sequential       0.21      0.66      0.32        29
#
#                    accuracy                           0.85      3218
#                   macro avg       0.57      0.72      0.61      3218
#                weighted avg       0.89      0.85      0.86      3218
#
# Accuracy: 0.8459, Precision: 0.8879, Recall: 0.8459, F1-Score: 0.8626
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.50      0.12         8
#             Computer Vision       0.96      0.89      0.92      1928
#                      Graphs       0.81      0.87      0.84       576
# Natural Language Processing       0.83      0.82      0.82       529
#      Reinforcement Learning       0.62      0.79      0.69       149
#                  Sequential       0.21      0.43      0.29        28
#
#                    accuracy                           0.86      3218
#                   macro avg       0.58      0.72      0.61      3218
#                weighted avg       0.89      0.86      0.87      3218
#
# Accuracy: 0.8633, Precision: 0.8894, Recall: 0.8633, F1-Score: 0.8740
# -----------------------------------
# Final Cross-Validated Results for TF-IDF (OvR Random Forest) - Abstract:
# Average Accuracy: 0.8511
# Average Precision: 0.8857
# Average Recall: 0.8511
# Average F1-Score: 0.8652

# %%
sentence_embeddings = compute_sentence_embeddings(abstracts)
train_random_forest_with_undersampling(sentence_embeddings, y, 'Sentence Transformer', 'Abstract')
# evaluate_clustering_metrics(sentence_embeddings, y, 'Sentence Transformer', 'Abstract')
# Out:
# Fold Results for Sentence Transformer (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.09      0.75      0.16         8
#             Computer Vision       0.87      0.72      0.78      1929
#                      Graphs       0.67      0.68      0.68       575
# Natural Language Processing       0.51      0.59      0.55       530
#      Reinforcement Learning       0.45      0.71      0.55       148
#                  Sequential       0.12      0.55      0.19        29
#
#                    accuracy                           0.69      3219
#                   macro avg       0.45      0.67      0.48      3219
#                weighted avg       0.75      0.69      0.71      3219
#
# Accuracy: 0.6869, Precision: 0.7475, Recall: 0.6869, F1-Score: 0.7090
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.09      0.75      0.16         8
#             Computer Vision       0.88      0.72      0.79      1929
#                      Graphs       0.62      0.68      0.65       575
# Natural Language Processing       0.47      0.57      0.52       529
#      Reinforcement Learning       0.43      0.63      0.51       149
#                  Sequential       0.13      0.48      0.21        29
#
#                    accuracy                           0.68      3219
#                   macro avg       0.44      0.64      0.47      3219
#                weighted avg       0.74      0.68      0.70      3219
#
# Accuracy: 0.6794, Precision: 0.7404, Recall: 0.6794, F1-Score: 0.7012
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.08      0.75      0.15         8
#             Computer Vision       0.87      0.69      0.77      1929
#                      Graphs       0.64      0.66      0.65       575
# Natural Language Processing       0.47      0.55      0.51       529
#      Reinforcement Learning       0.42      0.77      0.54       149
#                  Sequential       0.09      0.41      0.15        29
#
#                    accuracy                           0.66      3219
#                   macro avg       0.43      0.64      0.46      3219
#                weighted avg       0.73      0.66      0.69      3219
#
# Accuracy: 0.6611, Precision: 0.7312, Recall: 0.6611, F1-Score: 0.6853
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.09      0.86      0.16         7
#             Computer Vision       0.88      0.71      0.78      1928
#                      Graphs       0.71      0.70      0.71       576
# Natural Language Processing       0.49      0.54      0.51       529
#      Reinforcement Learning       0.45      0.77      0.57       149
#                  Sequential       0.09      0.55      0.15        29
#
#                    accuracy                           0.68      3218
#                   macro avg       0.45      0.69      0.48      3218
#                weighted avg       0.75      0.68      0.71      3218
#
# Accuracy: 0.6818, Precision: 0.7542, Recall: 0.6818, F1-Score: 0.7083
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.14      0.62      0.23         8
#             Computer Vision       0.88      0.72      0.79      1928
#                      Graphs       0.66      0.73      0.69       576
# Natural Language Processing       0.46      0.55      0.50       529
#      Reinforcement Learning       0.47      0.70      0.56       149
#                  Sequential       0.11      0.36      0.16        28
#
#                    accuracy                           0.69      3218
#                   macro avg       0.45      0.62      0.49      3218
#                weighted avg       0.74      0.69      0.71      3218
#
# Accuracy: 0.6930, Precision: 0.7426, Recall: 0.6930, F1-Score: 0.7103
# -----------------------------------
# Final Cross-Validated Results for Sentence Transformer (OvR Random Forest) - Abstract:
# Average Accuracy: 0.6804
# Average Precision: 0.7432
# Average Recall: 0.6804
# Average F1-Score: 0.7028

# %%
clip_embeddings = compute_clip_embeddings(abstracts)
train_random_forest_with_undersampling(clip_embeddings, y, 'CLIP', 'Abstract')
# evaluate_clustering_metrics(clip_embeddings, y, 'CLIP', 'Abstract')
# Out:
# Fold Results for CLIP (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.62      0.08         8
#             Computer Vision       0.83      0.61      0.70      1929
#                      Graphs       0.53      0.44      0.48       575
# Natural Language Processing       0.40      0.55      0.47       530
#      Reinforcement Learning       0.34      0.53      0.41       148
#                  Sequential       0.06      0.55      0.11        29
#
#                    accuracy                           0.56      3219
#                   macro avg       0.37      0.55      0.38      3219
#                weighted avg       0.67      0.56      0.60      3219
#
# Accuracy: 0.5648, Precision: 0.6736, Recall: 0.5648, F1-Score: 0.6033
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.50      0.08         8
#             Computer Vision       0.83      0.62      0.71      1929
#                      Graphs       0.49      0.40      0.44       575
# Natural Language Processing       0.40      0.51      0.45       529
#      Reinforcement Learning       0.31      0.57      0.40       149
#                  Sequential       0.03      0.28      0.06        29
#
#                    accuracy                           0.56      3219
#                   macro avg       0.35      0.48      0.36      3219
#                weighted avg       0.66      0.56      0.60      3219
#
# Accuracy: 0.5567, Precision: 0.6634, Recall: 0.5567, F1-Score: 0.5957
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.50      0.06         8
#             Computer Vision       0.82      0.60      0.69      1929
#                      Graphs       0.52      0.42      0.46       575
# Natural Language Processing       0.38      0.50      0.43       529
#      Reinforcement Learning       0.32      0.59      0.41       149
#                  Sequential       0.05      0.41      0.08        29
#
#                    accuracy                           0.55      3219
#                   macro avg       0.35      0.50      0.36      3219
#                weighted avg       0.66      0.55      0.59      3219
#
# Accuracy: 0.5464, Precision: 0.6614, Recall: 0.5464, F1-Score: 0.5874
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.71      0.08         7
#             Computer Vision       0.83      0.63      0.71      1928
#                      Graphs       0.54      0.41      0.47       576
# Natural Language Processing       0.39      0.49      0.43       529
#      Reinforcement Learning       0.32      0.64      0.43       149
#                  Sequential       0.04      0.31      0.07        29
#
#                    accuracy                           0.56      3218
#                   macro avg       0.36      0.53      0.37      3218
#                weighted avg       0.67      0.56      0.60      3218
#
# Accuracy: 0.5637, Precision: 0.6736, Recall: 0.5637, F1-Score: 0.6033
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - Abstract:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.38      0.06         8
#             Computer Vision       0.84      0.62      0.71      1928
#                      Graphs       0.50      0.45      0.47       576
# Natural Language Processing       0.38      0.48      0.42       529
#      Reinforcement Learning       0.34      0.56      0.42       149
#                  Sequential       0.05      0.50      0.09        28
#
#                    accuracy                           0.56      3218
#                   macro avg       0.36      0.50      0.36      3218
#                weighted avg       0.67      0.56      0.60      3218
#
# Accuracy: 0.5584, Precision: 0.6708, Recall: 0.5584, F1-Score: 0.6000
# -----------------------------------
# Final Cross-Validated Results for CLIP (OvR Random Forest) - Abstract:
# Average Accuracy: 0.5580
# Average Precision: 0.6685
# Average Recall: 0.5580
# Average F1-Score: 0.5979

# %%
tfidf_embeddings = compute_tfidf(readmes)
train_random_forest_with_undersampling(tfidf_embeddings, y, 'TF-IDF', 'GitHub README Content')
# evaluate_clustering_metrics(tfidf_embeddings, y, 'TF-IDF', 'GitHub README Content')
# Out:
# Fold Results for TF-IDF (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      0.38      0.11         8
#             Computer Vision       0.89      0.67      0.77      1929
#                      Graphs       0.63      0.67      0.65       575
# Natural Language Processing       0.52      0.61      0.56       530
#      Reinforcement Learning       0.38      0.51      0.44       148
#                  Sequential       0.03      0.31      0.06        29
#
#                    accuracy                           0.65      3219
#                   macro avg       0.42      0.53      0.43      3219
#                weighted avg       0.75      0.65      0.69      3219
#
# Accuracy: 0.6505, Precision: 0.7471, Recall: 0.6505, F1-Score: 0.6873
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.38      0.05         8
#             Computer Vision       0.88      0.65      0.75      1929
#                      Graphs       0.65      0.65      0.65       575
# Natural Language Processing       0.54      0.54      0.54       529
#      Reinforcement Learning       0.25      0.60      0.35       149
#                  Sequential       0.06      0.45      0.11        29
#
#                    accuracy                           0.63      3219
#                   macro avg       0.40      0.54      0.41      3219
#                weighted avg       0.74      0.63      0.67      3219
#
# Accuracy: 0.6263, Precision: 0.7423, Recall: 0.6263, F1-Score: 0.6688
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.50      0.02         8
#             Computer Vision       0.89      0.63      0.74      1929
#                      Graphs       0.63      0.62      0.63       575
# Natural Language Processing       0.53      0.50      0.52       529
#      Reinforcement Learning       0.38      0.57      0.45       149
#                  Sequential       0.11      0.52      0.18        29
#
#                    accuracy                           0.60      3219
#                   macro avg       0.43      0.56      0.42      3219
#                weighted avg       0.75      0.60      0.66      3219
#
# Accuracy: 0.6036, Precision: 0.7514, Recall: 0.6036, F1-Score: 0.6616
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.29      0.02         7
#             Computer Vision       0.88      0.67      0.76      1928
#                      Graphs       0.67      0.68      0.68       576
# Natural Language Processing       0.48      0.52      0.50       529
#      Reinforcement Learning       0.38      0.60      0.47       149
#                  Sequential       0.07      0.45      0.12        29
#
#                    accuracy                           0.64      3218
#                   macro avg       0.42      0.54      0.43      3218
#                weighted avg       0.75      0.64      0.68      3218
#
# Accuracy: 0.6429, Precision: 0.7460, Recall: 0.6429, F1-Score: 0.6830
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.12      0.38      0.18         8
#             Computer Vision       0.89      0.66      0.76      1928
#                      Graphs       0.65      0.70      0.67       576
# Natural Language Processing       0.52      0.53      0.52       529
#      Reinforcement Learning       0.26      0.68      0.38       149
#                  Sequential       0.05      0.32      0.08        28
#
#                    accuracy                           0.65      3218
#                   macro avg       0.41      0.55      0.43      3218
#                weighted avg       0.75      0.65      0.68      3218
#
# Accuracy: 0.6461, Precision: 0.7470, Recall: 0.6461, F1-Score: 0.6808
# -----------------------------------
# Final Cross-Validated Results for TF-IDF (OvR Random Forest) - GitHub README Content:
# Average Accuracy: 0.6339
# Average Precision: 0.7467
# Average Recall: 0.6339
# Average F1-Score: 0.6763

# %%
sentence_embeddings = compute_sentence_embeddings(readmes)
train_random_forest_with_undersampling(sentence_embeddings, y, 'Sentence Transformer', 'GitHub README Content')
# evaluate_clustering_metrics(sentence_embeddings, y, 'Sentence Transformer', 'GitHub README Content')
# Out:
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.62      0.05         8
#             Computer Vision       0.85      0.60      0.71      1929
#                      Graphs       0.55      0.53      0.54       575
# Natural Language Processing       0.39      0.49      0.43       530
#      Reinforcement Learning       0.29      0.52      0.37       148
#                  Sequential       0.07      0.38      0.12        29
#
#                    accuracy                           0.57      3219
#                   macro avg       0.36      0.52      0.37      3219
#                weighted avg       0.68      0.57      0.61      3219
#
# Accuracy: 0.5663, Precision: 0.6829, Recall: 0.5663, F1-Score: 0.6084
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      0.50      0.11         8
#             Computer Vision       0.84      0.60      0.70      1929
#                      Graphs       0.54      0.50      0.52       575
# Natural Language Processing       0.40      0.46      0.43       529
#      Reinforcement Learning       0.25      0.63      0.36       149
#                  Sequential       0.04      0.38      0.08        29
#
#                    accuracy                           0.56      3219
#                   macro avg       0.36      0.51      0.37      3219
#                weighted avg       0.68      0.56      0.60      3219
#
# Accuracy: 0.5592, Precision: 0.6764, Recall: 0.5592, F1-Score: 0.6000
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.62      0.05         8
#             Computer Vision       0.85      0.59      0.70      1929
#                      Graphs       0.53      0.51      0.52       575
# Natural Language Processing       0.36      0.46      0.40       529
#      Reinforcement Learning       0.37      0.65      0.48       149
#                  Sequential       0.06      0.38      0.10        29
#
#                    accuracy                           0.56      3219
#                   macro avg       0.37      0.54      0.37      3219
#                weighted avg       0.68      0.56      0.60      3219
#
# Accuracy: 0.5561, Precision: 0.6799, Recall: 0.5561, F1-Score: 0.5997
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.57      0.05         7
#             Computer Vision       0.84      0.60      0.70      1928
#                      Graphs       0.56      0.55      0.55       576
# Natural Language Processing       0.39      0.44      0.41       529
#      Reinforcement Learning       0.37      0.63      0.47       149
#                  Sequential       0.05      0.41      0.08        29
#
#                    accuracy                           0.56      3218
#                   macro avg       0.37      0.53      0.38      3218
#                weighted avg       0.69      0.56      0.61      3218
#
# Accuracy: 0.5649, Precision: 0.6851, Recall: 0.5649, F1-Score: 0.6095
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.62      0.06         8
#             Computer Vision       0.85      0.58      0.69      1928
#                      Graphs       0.55      0.55      0.55       576
# Natural Language Processing       0.36      0.45      0.40       529
#      Reinforcement Learning       0.35      0.59      0.44       149
#                  Sequential       0.05      0.46      0.10        28
#
#                    accuracy                           0.55      3218
#                   macro avg       0.37      0.54      0.37      3218
#                weighted avg       0.68      0.55      0.60      3218
#
# Accuracy: 0.5534, Precision: 0.6820, Recall: 0.5534, F1-Score: 0.5987
# -----------------------------------
# Final Cross-Validated Results for Sentence Transformer (OvR Random Forest) - GitHub README Content:
# Average Accuracy: 0.5600
# Average Precision: 0.6812
# Average Recall: 0.5600
# Average F1-Score: 0.6033

# %%
clip_embeddings = compute_clip_embeddings(readmes)
train_random_forest_with_undersampling(clip_embeddings, y, 'CLIP', 'GitHub README Content')
# evaluate_clustering_metrics(clip_embeddings, y, 'CLIP', 'GitHub README Content')
# Out:
# Fold Results for CLIP (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.38      0.03         8
#             Computer Vision       0.83      0.55      0.66      1929
#                      Graphs       0.50      0.44      0.47       575
# Natural Language Processing       0.35      0.45      0.40       530
#      Reinforcement Learning       0.19      0.38      0.26       148
#                  Sequential       0.03      0.28      0.05        29
#
#                    accuracy                           0.50      3219
#                   macro avg       0.32      0.41      0.31      3219
#                weighted avg       0.65      0.50      0.56      3219
#
# Accuracy: 0.4998, Precision: 0.6532, Recall: 0.4998, F1-Score: 0.5551
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.38      0.03         8
#             Computer Vision       0.82      0.52      0.64      1929
#                      Graphs       0.46      0.41      0.43       575
# Natural Language Processing       0.37      0.41      0.39       529
#      Reinforcement Learning       0.18      0.50      0.26       149
#                  Sequential       0.03      0.31      0.05        29
#
#                    accuracy                           0.48      3219
#                   macro avg       0.31      0.42      0.30      3219
#                weighted avg       0.65      0.48      0.53      3219
#
# Accuracy: 0.4772, Precision: 0.6454, Recall: 0.4772, F1-Score: 0.5349
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.50      0.02         8
#             Computer Vision       0.81      0.50      0.62      1929
#                      Graphs       0.48      0.41      0.44       575
# Natural Language Processing       0.34      0.41      0.37       529
#      Reinforcement Learning       0.23      0.44      0.31       149
#                  Sequential       0.03      0.24      0.05        29
#
#                    accuracy                           0.47      3219
#                   macro avg       0.32      0.42      0.30      3219
#                weighted avg       0.64      0.47      0.53      3219
#
# Accuracy: 0.4666, Precision: 0.6358, Recall: 0.4666, F1-Score: 0.5264
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.57      0.04         7
#             Computer Vision       0.82      0.53      0.65      1928
#                      Graphs       0.55      0.44      0.49       576
# Natural Language Processing       0.31      0.37      0.34       529
#      Reinforcement Learning       0.22      0.46      0.30       149
#                  Sequential       0.03      0.31      0.05        29
#
#                    accuracy                           0.49      3218
#                   macro avg       0.32      0.45      0.31      3218
#                weighted avg       0.65      0.49      0.54      3218
#
# Accuracy: 0.4857, Precision: 0.6488, Recall: 0.4857, F1-Score: 0.5442
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub README Content:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.38      0.02         8
#             Computer Vision       0.83      0.52      0.64      1928
#                      Graphs       0.50      0.47      0.49       576
# Natural Language Processing       0.34      0.41      0.37       529
#      Reinforcement Learning       0.23      0.42      0.30       149
#                  Sequential       0.02      0.14      0.03        28
#
#                    accuracy                           0.49      3218
#                   macro avg       0.32      0.39      0.31      3218
#                weighted avg       0.65      0.49      0.55      3218
#
# Accuracy: 0.4869, Precision: 0.6541, Recall: 0.4869, F1-Score: 0.5468
# -----------------------------------
# Final Cross-Validated Results for CLIP (OvR Random Forest) - GitHub README Content:
# Average Accuracy: 0.4833
# Average Precision: 0.6475
# Average Recall: 0.4833
# Average F1-Score: 0.5415

# %%
tfidf_embeddings = compute_tfidf(somef)
train_random_forest_with_undersampling(tfidf_embeddings, y_somef, 'TF-IDF', 'SOMEF descriptions')
# evaluate_clustering_metrics(tfidf_embeddings, y_somef, 'TF-IDF', 'SOMEF descriptions')
# Out:
# Fold Results for TF-IDF (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.29      0.01         7
#             Computer Vision       0.90      0.60      0.72      1610
#                      Graphs       0.70      0.67      0.69       489
# Natural Language Processing       0.51      0.51      0.51       445
#      Reinforcement Learning       0.39      0.56      0.46       120
#                  Sequential       0.04      0.46      0.08        24
#
#                    accuracy                           0.60      2695
#                   macro avg       0.42      0.51      0.41      2695
#                weighted avg       0.77      0.60      0.66      2695
#
# Accuracy: 0.5963, Precision: 0.7651, Recall: 0.5963, F1-Score: 0.6609
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.14      0.01         7
#             Computer Vision       0.88      0.64      0.74      1610
#                      Graphs       0.68      0.61      0.64       489
# Natural Language Processing       0.52      0.54      0.53       445
#      Reinforcement Learning       0.35      0.57      0.43       120
#                  Sequential       0.04      0.46      0.08        24
#
#                    accuracy                           0.61      2695
#                   macro avg       0.41      0.49      0.41      2695
#                weighted avg       0.75      0.61      0.67      2695
#
# Accuracy: 0.6096, Precision: 0.7531, Recall: 0.6096, F1-Score: 0.6661
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.57      0.02         7
#             Computer Vision       0.89      0.60      0.72      1610
#                      Graphs       0.71      0.58      0.64       488
# Natural Language Processing       0.52      0.48      0.50       446
#      Reinforcement Learning       0.34      0.47      0.40       120
#                  Sequential       0.04      0.42      0.07        24
#
#                    accuracy                           0.57      2695
#                   macro avg       0.42      0.52      0.39      2695
#                weighted avg       0.76      0.57      0.64      2695
#
# Accuracy: 0.5666, Precision: 0.7643, Recall: 0.5666, F1-Score: 0.6437
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.43      0.02         7
#             Computer Vision       0.90      0.61      0.73      1610
#                      Graphs       0.66      0.61      0.63       488
# Natural Language Processing       0.50      0.50      0.50       446
#      Reinforcement Learning       0.35      0.58      0.43       120
#                  Sequential       0.05      0.42      0.10        24
#
#                    accuracy                           0.59      2695
#                   macro avg       0.41      0.52      0.40      2695
#                weighted avg       0.76      0.59      0.65      2695
#
# Accuracy: 0.5866, Precision: 0.7560, Recall: 0.5866, F1-Score: 0.6510
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.14      0.02         7
#             Computer Vision       0.89      0.63      0.74      1610
#                      Graphs       0.67      0.67      0.67       488
# Natural Language Processing       0.48      0.54      0.51       446
#      Reinforcement Learning       0.35      0.53      0.42       120
#                  Sequential       0.03      0.39      0.06        23
#
#                    accuracy                           0.62      2694
#                   macro avg       0.41      0.48      0.40      2694
#                weighted avg       0.75      0.62      0.67      2694
#
# Accuracy: 0.6166, Precision: 0.7519, Recall: 0.6166, F1-Score: 0.6686
# -----------------------------------
# Final Cross-Validated Results for TF-IDF (OvR Random Forest) - SOMEF descriptions:
# Average Accuracy: 0.5951
# Average Precision: 0.7581
# Average Recall: 0.5951
# Average F1-Score: 0.6581

# %%
sentence_embeddings = compute_sentence_embeddings(somef)
train_random_forest_with_undersampling(sentence_embeddings, y_somef, 'Sentence Transformer', 'SOMEF descriptions')
# evaluate_clustering_metrics(sentence_embeddings, y_somef, 'Sentence Transformer', 'SOMEF descriptions')
# Out:
# Fold Results for Sentence Transformer (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.08      0.86      0.14         7
#             Computer Vision       0.87      0.63      0.73      1610
#                      Graphs       0.60      0.58      0.59       489
# Natural Language Processing       0.40      0.51      0.45       445
#      Reinforcement Learning       0.35      0.69      0.46       120
#                  Sequential       0.06      0.46      0.11        24
#
#                    accuracy                           0.60      2695
#                   macro avg       0.39      0.62      0.42      2695
#                weighted avg       0.71      0.60      0.64      2695
#
# Accuracy: 0.6048, Precision: 0.7123, Recall: 0.6048, F1-Score: 0.6418
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.57      0.13         7
#             Computer Vision       0.83      0.64      0.72      1610
#                      Graphs       0.60      0.54      0.57       489
# Natural Language Processing       0.42      0.48      0.45       445
#      Reinforcement Learning       0.34      0.57      0.43       120
#                  Sequential       0.05      0.50      0.09        24
#
#                    accuracy                           0.59      2695
#                   macro avg       0.39      0.55      0.40      2695
#                weighted avg       0.69      0.59      0.63      2695
#
# Accuracy: 0.5929, Precision: 0.6903, Recall: 0.5929, F1-Score: 0.6304
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.57      0.07         7
#             Computer Vision       0.83      0.63      0.72      1610
#                      Graphs       0.56      0.54      0.55       488
# Natural Language Processing       0.41      0.49      0.45       446
#      Reinforcement Learning       0.32      0.63      0.43       120
#                  Sequential       0.07      0.38      0.12        24
#
#                    accuracy                           0.59      2695
#                   macro avg       0.37      0.54      0.39      2695
#                weighted avg       0.68      0.59      0.62      2695
#
# Accuracy: 0.5896, Precision: 0.6808, Recall: 0.5896, F1-Score: 0.6226
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.71      0.09         7
#             Computer Vision       0.84      0.63      0.72      1610
#                      Graphs       0.57      0.56      0.56       488
# Natural Language Processing       0.39      0.46      0.42       446
#      Reinforcement Learning       0.33      0.71      0.45       120
#                  Sequential       0.08      0.46      0.14        24
#
#                    accuracy                           0.59      2695
#                   macro avg       0.38      0.59      0.40      2695
#                weighted avg       0.68      0.59      0.62      2695
#
# Accuracy: 0.5881, Precision: 0.6840, Recall: 0.5881, F1-Score: 0.6215
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      0.57      0.07         7
#             Computer Vision       0.85      0.63      0.72      1610
#                      Graphs       0.56      0.56      0.56       488
# Natural Language Processing       0.38      0.48      0.42       446
#      Reinforcement Learning       0.35      0.68      0.46       120
#                  Sequential       0.05      0.26      0.08        23
#
#                    accuracy                           0.59      2694
#                   macro avg       0.37      0.53      0.39      2694
#                weighted avg       0.69      0.59      0.62      2694
#
# Accuracy: 0.5876, Precision: 0.6864, Recall: 0.5876, F1-Score: 0.6225
# -----------------------------------
# Final Cross-Validated Results for Sentence Transformer (OvR Random Forest) - SOMEF descriptions:
# Average Accuracy: 0.5926
# Average Precision: 0.6908
# Average Recall: 0.5926
# Average F1-Score: 0.6278

# %%
clip_embeddings = compute_clip_embeddings(somef)
train_random_forest_with_undersampling(clip_embeddings, y_somef, 'CLIP', 'SOMEF descriptions')
# evaluate_clustering_metrics(clip_embeddings, y_somef, 'CLIP', 'SOMEF descriptions')
# Out:
# Fold Results for CLIP (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.29      0.02         7
#             Computer Vision       0.84      0.54      0.66      1610
#                      Graphs       0.53      0.47      0.50       489
# Natural Language Processing       0.35      0.46      0.40       445
#      Reinforcement Learning       0.27      0.52      0.35       120
#                  Sequential       0.04      0.38      0.07        24
#
#                    accuracy                           0.51      2695
#                   macro avg       0.34      0.44      0.33      2695
#                weighted avg       0.67      0.51      0.57      2695
#
# Accuracy: 0.5117, Precision: 0.6670, Recall: 0.5117, F1-Score: 0.5653
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.14      0.02         7
#             Computer Vision       0.82      0.56      0.66      1610
#                      Graphs       0.55      0.43      0.48       489
# Natural Language Processing       0.36      0.44      0.39       445
#      Reinforcement Learning       0.28      0.47      0.35       120
#                  Sequential       0.03      0.42      0.05        24
#
#                    accuracy                           0.51      2695
#                   macro avg       0.34      0.41      0.33      2695
#                weighted avg       0.66      0.51      0.57      2695
#
# Accuracy: 0.5095, Precision: 0.6595, Recall: 0.5095, F1-Score: 0.5653
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.01      0.14      0.02         7
#             Computer Vision       0.81      0.55      0.66      1610
#                      Graphs       0.51      0.48      0.49       488
# Natural Language Processing       0.32      0.46      0.38       446
#      Reinforcement Learning       0.24      0.52      0.33       120
#                  Sequential       0.04      0.21      0.06        24
#
#                    accuracy                           0.52      2695
#                   macro avg       0.32      0.39      0.32      2695
#                weighted avg       0.64      0.52      0.56      2695
#
# Accuracy: 0.5176, Precision: 0.6393, Recall: 0.5176, F1-Score: 0.5585
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      0.71      0.04         7
#             Computer Vision       0.82      0.54      0.65      1610
#                      Graphs       0.54      0.45      0.49       488
# Natural Language Processing       0.38      0.43      0.40       446
#      Reinforcement Learning       0.24      0.58      0.34       120
#                  Sequential       0.03      0.29      0.06        24
#
#                    accuracy                           0.50      2695
#                   macro avg       0.34      0.50      0.33      2695
#                weighted avg       0.66      0.50      0.56      2695
#
# Accuracy: 0.5032, Precision: 0.6614, Recall: 0.5032, F1-Score: 0.5587
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - SOMEF descriptions:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.43      0.05         7
#             Computer Vision       0.84      0.57      0.68      1610
#                      Graphs       0.53      0.46      0.49       488
# Natural Language Processing       0.33      0.43      0.37       446
#      Reinforcement Learning       0.24      0.46      0.31       120
#                  Sequential       0.01      0.13      0.02        23
#
#                    accuracy                           0.52      2694
#                   macro avg       0.33      0.41      0.32      2694
#                weighted avg       0.66      0.52      0.57      2694
#
# Accuracy: 0.5189, Precision: 0.6602, Recall: 0.5189, F1-Score: 0.5708
# -----------------------------------
# Final Cross-Validated Results for CLIP (OvR Random Forest) - SOMEF descriptions:
# Average Accuracy: 0.5122
# Average Precision: 0.6575
# Average Recall: 0.5122
# Average F1-Score: 0.5637

# %%
tfidf_embeddings = compute_tfidf(github_title)
train_random_forest_with_undersampling(tfidf_embeddings, y_complete, 'TF-IDF', 'GitHub Title')
# evaluate_clustering_metrics(tfidf_embeddings, y_complete, 'TF-IDF', 'GitHub Title')
# Out:
# /home/jenifer/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jenifer/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jenifer/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jenifer/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.00      0.00      0.00         2
#             Computer Vision       0.87      0.47      0.61       361
#                      Graphs       0.49      0.45      0.47       112
# Natural Language Processing       0.29      0.27      0.28        73
#      Reinforcement Learning       0.09      0.68      0.15        25
#                  Sequential       0.14      0.25      0.18         8
#
#                    accuracy                           0.45       581
#                   macro avg       0.31      0.35      0.28       581
#                weighted avg       0.68      0.45      0.52       581
#
# Accuracy: 0.4475, Precision: 0.6782, Recall: 0.4475, F1-Score: 0.5158
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.50      0.09         2
#             Computer Vision       0.83      0.45      0.59       361
#                      Graphs       0.35      0.70      0.46       112
# Natural Language Processing       0.33      0.33      0.33        73
#      Reinforcement Learning       0.15      0.32      0.20        25
#                  Sequential       0.18      0.25      0.21         8
#
#                    accuracy                           0.48       581
#                   macro avg       0.31      0.42      0.31       581
#                weighted avg       0.63      0.48      0.51       581
#
# Accuracy: 0.4750, Precision: 0.6338, Recall: 0.4750, F1-Score: 0.5060
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      0.50      0.06         2
#             Computer Vision       0.83      0.42      0.55       360
#                      Graphs       0.32      0.71      0.44       111
# Natural Language Processing       0.32      0.32      0.32        74
#      Reinforcement Learning       0.07      0.08      0.08        26
#                  Sequential       0.14      0.38      0.21         8
#
#                    accuracy                           0.45       581
#                   macro avg       0.29      0.40      0.28       581
#                weighted avg       0.62      0.45      0.48       581
#
# Accuracy: 0.4458, Precision: 0.6205, Recall: 0.4458, F1-Score: 0.4752
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.50      0.33      0.40         3
#             Computer Vision       0.89      0.50      0.64       360
#                      Graphs       0.40      0.82      0.54       111
# Natural Language Processing       0.28      0.45      0.35        74
#      Reinforcement Learning       0.35      0.35      0.35        26
#                  Sequential       0.20      0.29      0.24         7
#
#                    accuracy                           0.54       581
#                   macro avg       0.44      0.45      0.42       581
#                weighted avg       0.69      0.54      0.56       581
#
# Accuracy: 0.5422, Precision: 0.6854, Recall: 0.5422, F1-Score: 0.5632
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.00      0.00      0.00         2
#             Computer Vision       0.84      0.41      0.55       360
#                      Graphs       0.31      0.73      0.44       112
# Natural Language Processing       0.34      0.30      0.32        73
#      Reinforcement Learning       0.31      0.40      0.35        25
#                  Sequential       0.02      0.12      0.04         8
#
#                    accuracy                           0.45       580
#                   macro avg       0.31      0.33      0.28       580
#                weighted avg       0.64      0.45      0.48       580
#
# Accuracy: 0.4534, Precision: 0.6394, Recall: 0.4534, F1-Score: 0.4835
# -----------------------------------
# Final Cross-Validated Results for TF-IDF (OvR Random Forest) - GitHub Title:
# Average Accuracy: 0.4728
# Average Precision: 0.6515
# Average Recall: 0.4728
# Average F1-Score: 0.5087

# %%
sentence_embeddings = compute_sentence_embeddings(github_title)
train_random_forest_with_undersampling(sentence_embeddings, y_complete, 'Sentence Transformer', 'GitHub Title')
# evaluate_clustering_metrics(sentence_embeddings, y_complete, 'Sentence Transformer', 'GitHub Title')
# Out:
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.00      0.00      0.00         2
#             Computer Vision       0.83      0.55      0.66       361
#                      Graphs       0.50      0.40      0.45       112
# Natural Language Processing       0.37      0.41      0.39        73
#      Reinforcement Learning       0.21      0.64      0.31        25
#                  Sequential       0.06      0.62      0.11         8
#
#                    accuracy                           0.51       581
#                   macro avg       0.33      0.44      0.32       581
#                weighted avg       0.67      0.51      0.56       581
#
# Accuracy: 0.5077, Precision: 0.6679, Recall: 0.5077, F1-Score: 0.5613
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.50      0.12         2
#             Computer Vision       0.85      0.58      0.69       361
#                      Graphs       0.58      0.51      0.54       112
# Natural Language Processing       0.34      0.41      0.37        73
#      Reinforcement Learning       0.17      0.36      0.23        25
#                  Sequential       0.02      0.25      0.04         8
#
#                    accuracy                           0.53       581
#                   macro avg       0.34      0.44      0.33       581
#                weighted avg       0.69      0.53      0.59       581
#
# Accuracy: 0.5318, Precision: 0.6911, Recall: 0.5318, F1-Score: 0.5917
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      1.00      0.10         2
#             Computer Vision       0.83      0.53      0.65       360
#                      Graphs       0.44      0.47      0.45       111
# Natural Language Processing       0.33      0.36      0.35        74
#      Reinforcement Learning       0.17      0.27      0.21        26
#                  Sequential       0.01      0.12      0.03         8
#
#                    accuracy                           0.48       581
#                   macro avg       0.30      0.46      0.30       581
#                weighted avg       0.65      0.48      0.54       581
#
# Accuracy: 0.4819, Precision: 0.6456, Recall: 0.4819, F1-Score: 0.5409
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.67      0.13         3
#             Computer Vision       0.88      0.59      0.71       360
#                      Graphs       0.57      0.53      0.55       111
# Natural Language Processing       0.35      0.38      0.36        74
#      Reinforcement Learning       0.21      0.58      0.31        26
#                  Sequential       0.02      0.14      0.03         7
#
#                    accuracy                           0.55       581
#                   macro avg       0.35      0.48      0.35       581
#                weighted avg       0.71      0.55      0.61       581
#
# Accuracy: 0.5491, Precision: 0.7074, Recall: 0.5491, F1-Score: 0.6055
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      0.50      0.11         2
#             Computer Vision       0.86      0.54      0.67       360
#                      Graphs       0.49      0.46      0.47       112
# Natural Language Processing       0.28      0.37      0.32        73
#      Reinforcement Learning       0.23      0.44      0.30        25
#                  Sequential       0.03      0.38      0.06         8
#
#                    accuracy                           0.50       580
#                   macro avg       0.33      0.45      0.32       580
#                weighted avg       0.68      0.50      0.56       580
#
# Accuracy: 0.4983, Precision: 0.6754, Recall: 0.4983, F1-Score: 0.5592
# -----------------------------------
# Final Cross-Validated Results for Sentence Transformer (OvR Random Forest) - GitHub Title:
# Average Accuracy: 0.5138
# Average Precision: 0.6775
# Average Recall: 0.5138
# Average F1-Score: 0.5717

# %%
clip_embeddings = compute_clip_embeddings(github_title)
train_random_forest_with_undersampling(clip_embeddings, y_complete, 'CLIP', 'GitHub Title')
# evaluate_clustering_metrics(clip_embeddings, y_complete, 'CLIP', 'GitHub Title')
# Out:
# Fold Results for CLIP (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.00      0.00      0.00         2
#             Computer Vision       0.83      0.47      0.60       361
#                      Graphs       0.44      0.43      0.43       112
# Natural Language Processing       0.27      0.32      0.29        73
#      Reinforcement Learning       0.11      0.48      0.18        25
#                  Sequential       0.02      0.12      0.03         8
#
#                    accuracy                           0.43       581
#                   macro avg       0.28      0.30      0.26       581
#                weighted avg       0.64      0.43      0.50       581
#
# Accuracy: 0.4337, Precision: 0.6406, Recall: 0.4337, F1-Score: 0.4993
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.00      0.00      0.00         2
#             Computer Vision       0.84      0.48      0.61       361
#                      Graphs       0.52      0.49      0.51       112
# Natural Language Processing       0.27      0.38      0.32        73
#      Reinforcement Learning       0.08      0.16      0.10        25
#                  Sequential       0.04      0.38      0.08         8
#
#                    accuracy                           0.45       581
#                   macro avg       0.29      0.31      0.27       581
#                weighted avg       0.66      0.45      0.52       581
#
# Accuracy: 0.4527, Precision: 0.6608, Recall: 0.4527, F1-Score: 0.5224
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.03      1.00      0.06         2
#             Computer Vision       0.80      0.45      0.58       360
#                      Graphs       0.36      0.38      0.37       111
# Natural Language Processing       0.33      0.35      0.34        74
#      Reinforcement Learning       0.11      0.15      0.12        26
#                  Sequential       0.01      0.12      0.02         8
#
#                    accuracy                           0.41       581
#                   macro avg       0.27      0.41      0.25       581
#                weighted avg       0.61      0.41      0.48       581
#
# Accuracy: 0.4079, Precision: 0.6135, Recall: 0.4079, F1-Score: 0.4776
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.07      0.67      0.12         3
#             Computer Vision       0.88      0.49      0.63       360
#                      Graphs       0.47      0.43      0.45       111
# Natural Language Processing       0.26      0.36      0.31        74
#      Reinforcement Learning       0.08      0.27      0.13        26
#                  Sequential       0.03      0.29      0.06         7
#
#                    accuracy                           0.45       581
#                   macro avg       0.30      0.42      0.28       581
#                weighted avg       0.67      0.45      0.52       581
#
# Accuracy: 0.4527, Precision: 0.6707, Recall: 0.4527, F1-Score: 0.5223
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Title:
#                              precision    recall  f1-score   support
#
#                       Audio       0.00      0.00      0.00         2
#             Computer Vision       0.83      0.39      0.53       360
#                      Graphs       0.51      0.38      0.43       112
# Natural Language Processing       0.27      0.34      0.30        73
#      Reinforcement Learning       0.12      0.40      0.19        25
#                  Sequential       0.03      0.25      0.06         8
#
#                    accuracy                           0.38       580
#                   macro avg       0.29      0.29      0.25       580
#                weighted avg       0.65      0.38      0.46       580
#
# Accuracy: 0.3776, Precision: 0.6542, Recall: 0.3776, F1-Score: 0.4590
# -----------------------------------
# Final Cross-Validated Results for CLIP (OvR Random Forest) - GitHub Title:
# Average Accuracy: 0.4249
# Average Precision: 0.6480
# Average Recall: 0.4249
# Average F1-Score: 0.4961

# %%
tfidf_embeddings = compute_tfidf(github_keywords)
train_random_forest_with_undersampling(tfidf_embeddings, y_complete, 'TF-IDF', 'GitHub Keywords')
# evaluate_clustering_metrics(tfidf_embeddings, y_complete, 'TF-IDF', 'GitHub Keywords')
# Out:
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.04      1.00      0.08         2
#             Computer Vision       0.91      0.65      0.76       361
#                      Graphs       0.60      0.72      0.66       112
# Natural Language Processing       0.45      0.38      0.41        73
#      Reinforcement Learning       0.43      0.84      0.57        25
#                  Sequential       0.14      0.50      0.22         8
#
#                    accuracy                           0.64       581
#                   macro avg       0.43      0.68      0.45       581
#                weighted avg       0.76      0.64      0.68       581
#
# Accuracy: 0.6386, Precision: 0.7589, Recall: 0.6386, F1-Score: 0.6781
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.12      1.00      0.22         2
#             Computer Vision       0.88      0.66      0.75       361
#                      Graphs       0.54      0.68      0.60       112
# Natural Language Processing       0.35      0.53      0.43        73
#      Reinforcement Learning       0.42      0.56      0.48        25
#                  Sequential       0.08      0.12      0.10         8
#
#                    accuracy                           0.64       581
#                   macro avg       0.40      0.59      0.43       581
#                weighted avg       0.72      0.64      0.66       581
#
# Accuracy: 0.6351, Precision: 0.7157, Recall: 0.6351, F1-Score: 0.6598
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      1.00      0.04         2
#             Computer Vision       0.91      0.56      0.69       360
#                      Graphs       0.49      0.70      0.58       111
# Natural Language Processing       0.58      0.51      0.55        74
#      Reinforcement Learning       0.42      0.62      0.50        26
#                  Sequential       0.38      0.38      0.38         8
#
#                    accuracy                           0.58       581
#                   macro avg       0.47      0.63      0.46       581
#                weighted avg       0.75      0.58      0.64       581
#
# Accuracy: 0.5835, Precision: 0.7530, Recall: 0.5835, F1-Score: 0.6367
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.22      0.67      0.33         3
#             Computer Vision       0.89      0.62      0.73       360
#                      Graphs       0.48      0.71      0.57       111
# Natural Language Processing       0.38      0.47      0.42        74
#      Reinforcement Learning       0.57      0.62      0.59        26
#                  Sequential       0.11      0.57      0.18         7
#
#                    accuracy                           0.62       581
#                   macro avg       0.44      0.61      0.47       581
#                weighted avg       0.72      0.62      0.65       581
#
# Accuracy: 0.6196, Precision: 0.7198, Recall: 0.6196, F1-Score: 0.6478
# -----------------------------------
# Fold Results for TF-IDF (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.02      1.00      0.05         2
#             Computer Vision       0.85      0.61      0.71       360
#                      Graphs       0.60      0.69      0.64       112
# Natural Language Processing       0.30      0.29      0.30        73
#      Reinforcement Learning       0.50      0.68      0.58        25
#                  Sequential       0.18      0.25      0.21         8
#
#                    accuracy                           0.58       580
#                   macro avg       0.41      0.59      0.41       580
#                weighted avg       0.71      0.58      0.63       580
#
# Accuracy: 0.5810, Precision: 0.7051, Recall: 0.5810, F1-Score: 0.6277
# -----------------------------------
# Final Cross-Validated Results for TF-IDF (OvR Random Forest) - GitHub Keywords:
# Average Accuracy: 0.6116
# Average Precision: 0.7305
# Average Recall: 0.6116
# Average F1-Score: 0.6500

# %%
sentence_embeddings = compute_sentence_embeddings(github_keywords)
train_random_forest_with_undersampling(sentence_embeddings, y_complete, 'Sentence Transformer', 'GitHub Keywords')
# evaluate_clustering_metrics(sentence_embeddings, y_complete, 'Sentence Transformer', 'GitHub Keywords')
# Out:
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.12      0.50      0.20         2
#             Computer Vision       0.83      0.64      0.72       361
#                      Graphs       0.60      0.59      0.59       112
# Natural Language Processing       0.31      0.40      0.35        73
#      Reinforcement Learning       0.39      0.80      0.53        25
#                  Sequential       0.10      0.50      0.17         8
#
#                    accuracy                           0.60       581
#                   macro avg       0.39      0.57      0.43       581
#                weighted avg       0.69      0.60      0.63       581
#
# Accuracy: 0.6041, Precision: 0.6876, Recall: 0.6041, F1-Score: 0.6325
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.33      1.00      0.50         2
#             Computer Vision       0.86      0.68      0.76       361
#                      Graphs       0.60      0.50      0.54       112
# Natural Language Processing       0.33      0.49      0.40        73
#      Reinforcement Learning       0.29      0.56      0.38        25
#                  Sequential       0.11      0.50      0.17         8
#
#                    accuracy                           0.61       581
#                   macro avg       0.42      0.62      0.46       581
#                weighted avg       0.70      0.61      0.65       581
#
# Accuracy: 0.6145, Precision: 0.7039, Recall: 0.6145, F1-Score: 0.6458
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.14      1.00      0.25         2
#             Computer Vision       0.85      0.67      0.75       360
#                      Graphs       0.61      0.58      0.59       111
# Natural Language Processing       0.39      0.50      0.44        74
#      Reinforcement Learning       0.36      0.54      0.43        26
#                  Sequential       0.11      0.62      0.19         8
#
#                    accuracy                           0.63       581
#                   macro avg       0.41      0.65      0.44       581
#                weighted avg       0.71      0.63      0.66       581
#
# Accuracy: 0.6265, Precision: 0.7127, Recall: 0.6265, F1-Score: 0.6577
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.12      0.67      0.21         3
#             Computer Vision       0.88      0.66      0.76       360
#                      Graphs       0.66      0.66      0.66       111
# Natural Language Processing       0.38      0.54      0.44        74
#      Reinforcement Learning       0.62      0.69      0.65        26
#                  Sequential       0.08      0.57      0.15         7
#
#                    accuracy                           0.65       581
#                   macro avg       0.46      0.63      0.48       581
#                weighted avg       0.75      0.65      0.68       581
#
# Accuracy: 0.6472, Precision: 0.7487, Recall: 0.6472, F1-Score: 0.6836
# -----------------------------------
# Fold Results for Sentence Transformer (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.08      1.00      0.15         2
#             Computer Vision       0.84      0.64      0.72       360
#                      Graphs       0.65      0.61      0.63       112
# Natural Language Processing       0.32      0.40      0.35        73
#      Reinforcement Learning       0.36      0.64      0.46        25
#                  Sequential       0.10      0.50      0.16         8
#
#                    accuracy                           0.60       580
#                   macro avg       0.39      0.63      0.41       580
#                weighted avg       0.70      0.60      0.64       580
#
# Accuracy: 0.6017, Precision: 0.7028, Recall: 0.6017, F1-Score: 0.6385
# -----------------------------------
# Final Cross-Validated Results for Sentence Transformer (OvR Random Forest) - GitHub Keywords:
# Average Accuracy: 0.6188
# Average Precision: 0.7111
# Average Recall: 0.6188
# Average F1-Score: 0.6516

# %%
clip_embeddings = compute_clip_embeddings(github_keywords)
train_random_forest_with_undersampling(clip_embeddings, y_complete, 'CLIP', 'GitHub Keywords')
# evaluate_clustering_metrics(clip_embeddings, y_complete, 'CLIP', 'GitHub Keywords')
# Out:
# Fold Results for CLIP (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.10      0.50      0.17         2
#             Computer Vision       0.85      0.59      0.70       361
#                      Graphs       0.57      0.57      0.57       112
# Natural Language Processing       0.24      0.38      0.29        73
#      Reinforcement Learning       0.39      0.80      0.53        25
#                  Sequential       0.07      0.38      0.12         8
#
#                    accuracy                           0.56       581
#                   macro avg       0.37      0.54      0.40       581
#                weighted avg       0.69      0.56      0.60       581
#
# Accuracy: 0.5645, Precision: 0.6891, Recall: 0.5645, F1-Score: 0.6043
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.12      1.00      0.22         2
#             Computer Vision       0.84      0.65      0.73       361
#                      Graphs       0.59      0.47      0.52       112
# Natural Language Processing       0.29      0.48      0.36        73
#      Reinforcement Learning       0.25      0.48      0.33        25
#                  Sequential       0.07      0.25      0.11         8
#
#                    accuracy                           0.58       581
#                   macro avg       0.36      0.55      0.38       581
#                weighted avg       0.69      0.58      0.62       581
#
# Accuracy: 0.5800, Precision: 0.6862, Recall: 0.5800, F1-Score: 0.6172
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.09      1.00      0.16         2
#             Computer Vision       0.88      0.65      0.75       360
#                      Graphs       0.65      0.55      0.60       111
# Natural Language Processing       0.35      0.51      0.42        74
#      Reinforcement Learning       0.28      0.54      0.37        26
#                  Sequential       0.11      0.50      0.17         8
#
#                    accuracy                           0.61       581
#                   macro avg       0.39      0.63      0.41       581
#                weighted avg       0.73      0.61      0.65       581
#
# Accuracy: 0.6093, Precision: 0.7264, Recall: 0.6093, F1-Score: 0.6500
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.06      1.00      0.11         3
#             Computer Vision       0.86      0.55      0.67       360
#                      Graphs       0.65      0.57      0.61       111
# Natural Language Processing       0.33      0.50      0.40        74
#      Reinforcement Learning       0.50      0.50      0.50        26
#                  Sequential       0.08      0.71      0.15         7
#
#                    accuracy                           0.55       581
#                   macro avg       0.41      0.64      0.40       581
#                weighted avg       0.72      0.55      0.61       581
#
# Accuracy: 0.5491, Precision: 0.7209, Recall: 0.5491, F1-Score: 0.6063
# -----------------------------------
# Fold Results for CLIP (OvR Random Forest) - GitHub Keywords:
#                              precision    recall  f1-score   support
#
#                       Audio       0.05      0.50      0.10         2
#             Computer Vision       0.84      0.60      0.70       360
#                      Graphs       0.59      0.62      0.61       112
# Natural Language Processing       0.27      0.38      0.32        73
#      Reinforcement Learning       0.38      0.68      0.49        25
#                  Sequential       0.11      0.50      0.18         8
#
#                    accuracy                           0.58       580
#                   macro avg       0.37      0.55      0.40       580
#                weighted avg       0.69      0.58      0.61       580
#
# Accuracy: 0.5776, Precision: 0.6850, Recall: 0.5776, F1-Score: 0.6134
# -----------------------------------
# Final Cross-Validated Results for CLIP (OvR Random Forest) - GitHub Keywords:
# Average Accuracy: 0.5761
# Average Precision: 0.7015
# Average Recall: 0.5761
# Average F1-Score: 0.6182
